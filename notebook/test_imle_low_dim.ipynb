# %%
import sys

sys.path.append('../imleSource/python/')
sys.path.append('../imleSource/build/lib/')
sys.path.append('../')

# %%
import imle

# %%
noise_value=0.3

# %%
model = imle.Imle(alpha=0.995,Psi0=[noise_value**2] * 1, sigma0=pi/2, wsigma=1**1, wSigma=1**1, wNu=1,wLambda=0.1, wPsi=1, p0=0.1, multiValuedSignificance=0.8, nSolMax=6)

# %%
z_train=arange(-2*pi, 2*pi, 0.1)
z_train.shape=(max(z_train.shape),1)

# %%
x_train=cos(z_train)+noise_value*rand(*z_train.shape)

# %%
x_train.shape
# Out:
# (126, 1)

# %%
for i, (z, x) in enumerate(zip(z_train, x_train)):
    if i % 1000 == 0:
        print i
    
    model.update(z, x)
# Out:
# 0

# %%
print model.number_of_experts
# Out:
# 7

# %%
mu=array([model.get_joint_mu(e) for e in range(model.number_of_experts)])
mu.shape
# Out:
# (7, 2)

# %%
COLORS = ['r', 'g', 'b', 'k', 'm']*10

# %%
plot(z_train.T,x_train.T, 'xb')
plot(mu[:,0], mu[:,1],'ob')
a=subplot(111)
gmm=model.to_gmm()
els = gmm.get_display_ellipses2D(COLORS)
for el in els:
    a.add_patch(el)
for goal in arange(-8,3,0.05):
    sols=model.predict([goal])
    #plot(tile(goal,[sols.shape[0],1]), sols, 'or')

# %%
diag?

# %%
gmm=model.to_gmm()

# %%
model.get_sigma(1)
# Out:
# array([[ 0.00034629]])

# %%
COLORS = ['r', 'g', 'b', 'k', 'm']

# %%
a=subplot(111)
els = gmm.get_display_ellipses2D(COLORS)
for el in els:
    a.add_patch(el)
axis([-10,10,-4,4])
# Out:
# [-10, 10, -4, 4]

# %%
gca().add_patch(el)

# %%
import test_inf_gmm

# %%
# %run test_inf_gmm

# %%
# %run ../test_inf_gmm.py

# %%
from sklearn.mixture import GMM

# %%
GMM(n_components=3, co)

# %%
del GMM
