# %%
import librosa

# %%
"""PyAudio example: Record a few seconds of audio and save to a WAVE file."""

import pyaudio
import wave

CHUNK = 1024
FORMAT = pyaudio.paInt16
CHANNELS = 2
RATE = 44100
RECORD_SECONDS = 5
WAVE_OUTPUT_FILENAME = "output.wav"

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("* recording")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("* done recording")

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# * recording
# * done recording

# %%
"""PyAudio Example: Play a WAVE file."""

import pyaudio
import wave
import sys
import time

CHUNK = 1024

WAVE_INPUT_FILENAME = "../data/kick_01.wav"
WAVE_INPUT_FILENAME = 'output.wav'


p = pyaudio.PyAudio()

wf_in = wave.open(WAVE_INPUT_FILENAME, 'rb')
form = p.get_format_from_width(wf_in.getsampwidth())
channels = wf_in.getnchannels()
rate = wf_in.getframerate()

stream_out = p.open(format=form,
                channels=channels,
                rate=rate,
                output=True)

stream_in = p.open(format=form,
                channels=channels,
                rate=rate,
                input=True,
                frames_per_buffer=CHUNK)
frames = []
for _ in range(10):
    data = wf_in.readframes(CHUNK)
    while data != '':
        stream_out.write(data)
        frames.append(stream_in.read(CHUNK))
        #data = wf_.readframes(CHUNK)
    print 'rewind'
    wf.rewind()
    time.sleep(rand())
wf_out = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf_out.setnchannels(channels)
wf_out.setsampwidth(p.get_sample_size(form))
wf_out.setframerate(rate)
wf_out.writeframes(b''.join(frames))
wf.close()
stream_in.stop_stream()
stream_out.close()
stream_out.stop_stream()
stream_in.close()

p.terminate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c7c060ecd6b0> in <module>()
#      34     while data != '':
#      35         stream_out.write(data)
# ---> 36         frames.append(stream_in.read(CHUNK))
#      37         #data = wf_.readframes(CHUNK)
#      38     print 'rewind'
#
# /usr/lib/pymodules/python2.7/pyaudio.pyc in read(self, num_frames)
#     562                           paCanNotReadFromAnOutputOnlyStream)
#     563
# --> 564         return pa.read_stream(self._stream, num_frames)
#     565
#     566     def get_read_available(self):
#
# KeyboardInterrupt:

# %%
frames
# Out:
# ['\xa5\x05\xcb\x04\x1d\x06]\x04\x1a\x06\xa1\x04\x1d\x06\xda\x03\xeb\x06\xe2\x03$\x06\x0f\x04\x96\x06(\x04o\x06\xd9\x03\x91\x06\x12\x04p\x06]\x04\x18\x07=\x04\xac\x06m\x04\x9d\x06\x15\x04\xff\x06\x14\x04X\x06\x1d\x04s\x06\x92\x04\x9d\x06\x07\x04&\x07\xa1\x03F\x07\xd1\x03\xaa\x06C\x04\xa8\x07\xdc\x04\x0c\x07\xf1\x04i\x07\x10\x05\xcb\x07\xe5\x04\x93\x07*\x05/\x07\x91\x04\x87\x07\x1a\x04o\x07\x9a\x04\x98\x07{\x04\xf2\x07\xfa\x03u\x07Q\x04\xcc\x07\xab\x04#\x07O\x04o\x07\xb0\x04d\x07\xcc\x03&\x07\xd6\x04e\x07\xd6\x04]\x07/\x05t\x07\xae\x04{\x07\x96\x04y\x07\x03\x04\xbc\x07\xf4\x03\xc9\x07\xa7\x03o\x07\x9e\x03\x06\x07\xca\x04\xcf\x06\n\x05\x11\x07\xb7\x04\xdb\x06\x85\x04\x99\x06\xf1\x03v\x07q\x04\x89\x06\xb4\x04\x18\x079\x04\xe2\x06\xff\x03\x1f\x07\xff\x03\xcd\x06#\x04A\x07\x89\x04h\x06\x7f\x046\x06\xe5\x03\x99\x05K\x04"\x06\x0f\x04\x99\x05w\x04\\\x06F\x04 \x06\xb8\x03\xdb\x05\xca\x03\x94\x05\xdd\x03\xa4\x05\x84\x03\xa6\x05\xc2\x03\x89\x05\xd8\x03\xb2\x05\x19\x03\xc2\x05\'\x03 \x05\xad\x03Y
# ...

# %%
y, sr = librosa.load('output.wav')

# %%
D = np.abs(librosa.stft(y))

# %%
librosa.display.specshow(D, sr=sr, y_axis='log')
# Out:
# /usr/local/lib/python2.7/dist-packages/librosa-0.2.2_dev-py2.7.egg/librosa/display.py:375: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/librosa-0.2.2_dev-py2.7.egg/librosa/display.py:375: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/librosa-0.2.2_dev-py2.7.egg/librosa/display.py:375: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/librosa-0.2.2_dev-py2.7.egg/librosa/display.py:375: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/librosa-0.2.2_dev-py2.7.egg/librosa/display.py:375: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ...

# %%
CQT = librosa.cqt(y, sr, fmin=55, fmax=880)
librosa.display.specshow(CQT, sr=sr, y_axis='cqt_note', fmin=55, fmax=880)
# Out:
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# ...

# %%
# Draw a chromagram with pitch classes
C = librosa.feature.chromagram(y, sr)
librosa.display.specshow(C, y_axis='chroma')

# %%
tempo, beats = librosa.beat.beat_track( y, sr )
# Out:
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)

# %%
tempo
# Out:
# 133.36693548387098

# %%
beats
# Out:
# array([ 151,  307,  480,  644,  799,  946, 1086, 1234, 1380, 1523])

# %%
plot(beats, ones_like(beats), 'o')

# %%
wav_path = '/home/clement/Bureau/Poppy leap motion bras séparés/'

# %%
import glob
import os

# %%
linspace(0, 10, 4)
# Out:
# array([  0.        ,   3.33333333,   6.66666667,  10.        ])

# %%
tempos = []
for wav in glob.glob(os.path.join(wav_path, '*')):
    y, sr = librosa.load(wav)
    sub_tempos = []
    for sub_y in linspace(0, len(y), 4)[:-1]:
        y_part = y[int(sub_y):int(sub_y + len(y)/4)]
        tempo, beats = librosa.beat.beat_track( y_part, sr )
        sub_tempos.append(tempo)
    tempos.append(sub_tempos)
# Out:
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# /usr/lib/python2.7/dist-packages/scipy/fftpack/basic.py:121: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   z = zeros(s,x.dtype.char)
# ...

# %%
plot(tempos, 'o')

# %%
glob.glob(os.path.join(wav_path, '*'))
# Out:
# ['/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras droit 1-output-1-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras droit 6-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras droit 3-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras droit 8-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras gauche 8-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras droit 5-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras gauche 10-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras gauche 6-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras droit 9-output-1.wav',
#  '/home/clement/Bureau/Poppy leap motion bras s\xc3\xa9par\xc3\xa9s/Bras droit 2-output-1.wav',
# ...
