# %%
from explauto.environment import environments

# %%
from explauto.experiment import Experiment, make_settings

s = make_settings(environment='music',
                  babbling_mode='goal', 
                  interest_model='discretized_progress',
                  sensorimotor_model='nearest_neighbor')

expe = Experiment.from_settings(s)

# %%
# %pylab inline
ax = axes()
expe.env.plot_boxes(ax)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
expe.run(100)

# %%
# %pylab inline
ax = subplot(121)
expe.log.scatter_plot(ax, (('sensori', [0, 1]),))
ax = subplot(122)
expe.log.scatter_plot(ax, (('sensori', [1, 2]),), ms_limits=False)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from explauto.utils.sound.player import Sampler
from explauto.utils.sound.recorder import Recorder

# %%
wav_files = ['../data/piano_notes/a.wav', '../data/piano_notes/b.wav', '../data/piano_notes/c.wav']
sampler = Sampler(wav_files)

# %%
sampler.play(1)

# %%
rec = Recorder()

# %%
rec.start()
sampler.play(0, wait=True)
rec.stop()

# %%
plot(rec.data)

# %%
# %pylab inline
plot(r.get_data())
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.add_subplot(111)
r = array([[-1,-2],[1,2]])
import itertools
[ax.plot(*zip(s1, s2), color="b") for s1, s2 in list(itertools.combinations(itertools.product(*zip(*r)), 2)) if (array(s1) == array(s2)).sum() == len(s1) - 1]
#    if norm(s1 -s2) <= max_len_edge:
#        ax.plot(*zip(s1, s2), color="b")
# Out:
# [[<matplotlib.lines.Line2D at 0x50a76d0>],
#  [<matplotlib.lines.Line2D at 0x50a7bd0>],
#  [<matplotlib.lines.Line2D at 0x5243110>],
#  [<matplotlib.lines.Line2D at 0x5243610>]]

# %%
# %pylab inline
ax = axes()
r = [[-1, 1], [-1, 1]]
print product(*r)
for s, e in itertools.combinations(np.array(list(product(*r))), 2):
    print s, e
    if np.sum(np.abs(s-e)) == r[1]-r[0]:
        ax.plot(*zip(s,e), color="b")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b00dfe6226e7> in <module>()
#       2 ax = axes()
#       3 r = [[-1, 1], [-1, 1]]
# ----> 4 print product(*r)
#       5 for s, e in itertools.combinations(np.array(list(product(*r))), 2):
#       6     print s, e
#
# /usr/lib/python2.7/dist-packages/numpy/core/fromnumeric.pyc in product(a, axis, dtype, out, keepdims)
#    1723
#    1724     """
# -> 1725     return um.multiply.reduce(a, axis=axis, dtype=dtype, out=out, keepdims=keepdims)
#    1726
#    1727
#
# TypeError: an integer is required

# %%
s, r = load('../data/4409__pinkyfinger__piano-notes-1-octave/68437__pinkyfinger__piano-a.wav')

# %%
plot(s)

# %%
from explauto.utils.sound.pitch_tracker import estimate_tuning

# %%
estimate_tuning(s,r)
# Out:
# 0.44000000000000006

# %%
import librosa
y, sr = librosa.loa
librosa.feature.chromagram(y=y, sr=sr)
